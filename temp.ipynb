# %% [markdown]
# # Upload MIMIC-IV csv files

# %%
# !lamin load laminlabs/lamindb-dev-datasets

# %%
import lamindb as ln

# %%
ln.settings.transform.stem_uid = "KqDjPeFHgrFk"
ln.settings.transform.version = "1"

ln.track()

# %%
artifact = ln.Artifact(
    "./mimic-iv-demo-data-in-the-omop-common-data-model-0.9/1_omop_data_csv",
    description=(
        "MIMIC-IV OMOP CDM demo data, from:"
        " https://physionet.org/content/mimic-iv-demo-omop/0.9/"
    ),
)

# %%
artifact.save()

# %%
ln.finish()
